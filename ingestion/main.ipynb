# %%
import subprocess
import sys

# %%
PIPELINE = [
    "../etl/landing2raw.ipynb",
    "../etl/raw2cleansed.ipynb",
    #"../etl/cleansed2curated.ipynb",
]

# %%
def run_step(script: str) -> None:
    print(f"\n{'='*50}\n▶ Iniciando: {script}\n{'='*50}")
    result = subprocess.run(
        ["jupyter", "nbconvert", "--to", "notebook", "--execute", "--inplace", script],
        check=False,
    )
    if result.returncode != 0:
        print(f"\n✗ Falha em '{script}' (exit code {result.returncode}). Pipeline interrompido.")
        sys.exit(result.returncode)
    print(f"✔ Concluído: {script}")

# %%
for script in PIPELINE:
    run_step(script)

print("\n✔ Pipeline concluído com sucesso.")
# Out:
# ==================================================
# ▶ Iniciando: ../etl/landing2raw.ipynb
# ==================================================
# [NbConvertApp] Converting notebook ../etl/landing2raw.ipynb to notebook
# ERROR StatusLogger Reconfiguration failed: No configuration found for 'c387f44' at 'null' in 'null'
# ERROR StatusLogger Reconfiguration failed: No configuration found for 'Default' at 'null' in 'null'
# 26/04/21 19:57:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/21 19:57:13 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/04/21 19:57:21 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 26/04/21 19:57:26 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# 26/04/21 19:57:28 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# [NbConvertApp] Writing 9271 bytes to ../etl/landing2raw.ipynb
# ✔ Concluído: ../etl/landing2raw.ipynb
#
# ==================================================
# ▶ Iniciando: ../etl/raw2cleansed.ipynb
# ==================================================
# [NbConvertApp] Converting notebook ../etl/raw2cleansed.ipynb to notebook
# ERROR StatusLogger Reconfiguration failed: No configuration found for 'c387f44' at 'null' in 'null'
# ERROR StatusLogger Reconfiguration failed: No configuration found for 'Default' at 'null' in 'null'
# 26/04/21 19:57:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/21 19:57:52 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/04/21 19:57:58 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 26/04/21 19:58:03 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# 26/04/21 19:58:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/21 19:58:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/21 19:58:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/21 19:58:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 26/04/21 19:58:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 63.33% for 12 writers
# 26/04/21 19:58:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 69.09% for 11 writers
# 26/04/21 19:58:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/21 19:58:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/21 19:58:07 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# ✔ Concluído: ../etl/raw2cleansed.ipynb
#
# ✔ Pipeline concluído com sucesso.
# [NbConvertApp] Writing 17280 bytes to ../etl/raw2cleansed.ipynb
